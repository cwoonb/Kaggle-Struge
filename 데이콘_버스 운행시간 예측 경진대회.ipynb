# %%
import pandas as pd
import numpy as np
import seaborn as sns
import matplotlib.pyplot as plt
from sklearn.preprocessing import LabelEncoder # 라벨 인코더

# 글꼴 한글 설정
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus= False)
plt.style.use('ggplot')
pd.options.display.max_columns  = 100
sns.set()

# %% [markdown]
# # 데이터 불러오기 ( train, y_train, y_test )

# %%
train = pd.read_csv('data/train.csv')
print(train.shape)

X_test = pd.read_csv('data/test.csv')
print(X_test.shape)

y_test = pd.read_csv('data/submission_제출양식.csv')
print(y_test.shape)
# Out:
# (210457, 14)
# (91774, 13)
# (91774, 2)

# %%
train.columns
# Out:
# Index(['id', 'date', 'route_id', 'vh_id', 'route_nm', 'now_latitude',
#        'now_longitude', 'now_station', 'now_arrive_time', 'distance',
#        'next_station', 'next_latitude', 'next_longitude', 'next_arrive_time'],
#       dtype='object')

# %%
X_test.head()
# Out:
#        id        date   route_id    vh_id route_nm  now_latitude  \
# 0  210457  2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458  2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459  2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460  2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461  2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude
# 0      33.458783      126.557353
# 1      33.459893      126.561624
# 2      33.478850      126.488350
# 3      33.480700      126.489933
# 4      33.482077      126.485355

# %%
y_test.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %% [markdown]
# ## 요일 생성

# %% [markdown]
# ### train

# %%
train['date'] = pd.to_datetime(train['date'].astype(str))
train['요일'] = train['date'].dt.dayofweek
train['일'] = train['date'].dt.day
weekday = "월화수목금토일"
# train["요일명"] = train["요일"].map(lambda x : weekday[x])
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#   now_station now_arrive_time  distance     next_station  next_latitude  \
# 0     제주대학교입구             06시     266.0             제대마을      33.457724
# 1        제대마을             06시     333.0            제대아파트      33.458783
# 2       제대아파트             06시     415.0            제주대학교      33.459893
# 3   남국원(아라방면)             06시     578.0  제주여자중고등학교(아라방면)      33.484860
# 4         도호동             07시     374.0              은남동      33.485822
#
#    next_longitude  next_arrive_time  요일   일
# 0      126.554014                24   1  15
# 1      126.557353                36   1  15
# 2      126.561624                40   1  15
# 3      126.542928                42   1  15
# 4      126.490897                64   1  15

# %%
train.describe(include="object")
# Out:
#        route_nm now_station now_arrive_time next_station
# count    210457      210457          210457       210457
# unique       21         348              20          351
# top      365-22   남국원(아라방면)             08시          은남동
# freq      31941        3361           13838         3519

# %% [markdown]
# ### X_test

# %%
X_test['date'] = pd.to_datetime(X_test['date'].astype(str))
X_test['요일'] = X_test['date'].dt.dayofweek
X_test['일'] = X_test['date'].dt.day
weekday = "월화수목금토일"
# X_test["요일명"] = X_test["요일"].map(lambda x : weekday[x])
X_test.head()
# Out:
#        id       date   route_id    vh_id route_nm  now_latitude  \
# 0  210457 2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458 2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459 2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460 2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461 2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance next_station  \
# 0     126.554014         제대마을             07시     333.0        제대아파트
# 1     126.557353        제대아파트             07시     415.0        제주대학교
# 2     126.483833  한라중학교/부영아파트             08시     417.0      대림2차아파트
# 3     126.488350      대림2차아파트             08시     334.0    연동대림1차아파트
# 4     126.489933    연동대림1차아파트             08시     550.0        케이티앤지
#
#    next_latitude  next_longitude  요일   일
# 0      33.458783      126.557353   1  29
# 1      33.459893      126.561624   1  29
# 2      33.478850      126.488350   1  29
# 3      33.480700      126.489933   1  29
# 4      33.482077      126.485355   1  29

# %%
X_test.describe(include="object")
# Out:
#        route_nm now_station now_arrive_time next_station
# count     91774       91774           91774        91774
# unique       21         349              19          350
# top      365-22     아라주공아파트             18시          은남동
# freq      14293        1487            6216         1550

# %% [markdown]
# # 정류장 명 숫자로 변경

# %% [markdown]
# ### train

# %%
# 인코더 생성
station_encoder = LabelEncoder()
station_encoder

# 인코딩
_station = list(train['now_station'].values) + list(train['next_station'].values) # train 의 모든 정류장 이름
station_set = set(_station)

print(len(station_set))
# Out:
# 351

# %%
station_encoder.fit(list(station_set))
# Out:
# LabelEncoder()

# %%
# 학습, 시험 데이터의 정류장 정보 치환
train['now_station'] = station_encoder.transform(train['now_station'])
train['next_station'] = station_encoder.transform(train['next_station'])
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          239             06시     266.0           227      33.457724
# 1          227             06시     333.0           228      33.458783
# 2          228             06시     415.0           235      33.459893
# 3           41             06시     578.0           249      33.484860
# 4           63             07시     374.0           221      33.485822
#
#    next_longitude  next_arrive_time  요일   일
# 0      126.554014                24   1  15
# 1      126.557353                36   1  15
# 2      126.561624                40   1  15
# 3      126.542928                42   1  15
# 4      126.490897                64   1  15

# %% [markdown]
# ### X_test

# %%
# 인코더 생성
station_encoder = LabelEncoder()
station_encoder

# 인코딩
_station = list(X_test['now_station'].values) + list(X_test['next_station'].values) # X_test 의 모든 정류장 이름
station_set = set(_station)

print(len(station_set))
# Out:
# 351

# %%
station_encoder.fit(list(station_set))
# Out:
# LabelEncoder()

# %%
# 학습, 시험 데이터의 정류장 정보 치환
X_test['now_station'] = station_encoder.transform(X_test['now_station'])
X_test['next_station'] = station_encoder.transform(X_test['next_station'])
X_test.head()
# Out:
#        id       date   route_id    vh_id route_nm  now_latitude  \
# 0  210457 2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458 2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459 2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460 2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461 2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance  next_station  \
# 0     126.554014          227             07시     333.0           228
# 1     126.557353          228             07시     415.0           235
# 2     126.483833          323             08시     417.0            59
# 3     126.488350           59             08시     334.0           183
# 4     126.489933          183             08시     550.0           285
#
#    next_latitude  next_longitude  요일   일
# 0      33.458783      126.557353   1  29
# 1      33.459893      126.561624   1  29
# 2      33.478850      126.488350   1  29
# 3      33.480700      126.489933   1  29
# 4      33.482077      126.485355   1  29

# %% [markdown]
# # 요일 설정

# %% [markdown]
# ### train

# %%
train['date'] = pd.to_datetime(train['date'])
train['weekday'] = train['date'].dt.weekday
train['weekday'].value_counts()
# Out:
# 1    31311
# 3    30968
# 2    30818
# 0    30353
# 4    30003
# 5    28806
# 6    28198
# Name: weekday, dtype: int64

# %% [markdown]
# ### X_test

# %%
X_test['date'] = pd.to_datetime(X_test['date'])
X_test['weekday'] = X_test['date'].dt.weekday
X_test['weekday'].value_counts()
# Out:
# 1    26435
# 4    13541
# 0    13503
# 6    12609
# 5    10845
# 3    10182
# 2     4659
# Name: weekday, dtype: int64

# %% [markdown]
# ## 주말 평일 설정

# %%
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          239             06시     266.0           227      33.457724
# 1          227             06시     333.0           228      33.458783
# 2          228             06시     415.0           235      33.459893
# 3           41             06시     578.0           249      33.484860
# 4           63             07시     374.0           221      33.485822
#
#    next_longitude  next_arrive_time  요일   일  weekday
# 0      126.554014                24   1  15        1
# 1      126.557353                36   1  15        1
# 2      126.561624                40   1  15        1
# 3      126.542928                42   1  15        1
# 4      126.490897                64   1  15        1

# %%
X_test.head()
# Out:
#        id       date   route_id    vh_id route_nm  now_latitude  \
# 0  210457 2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458 2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459 2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460 2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461 2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance  next_station  \
# 0     126.554014          227             07시     333.0           228
# 1     126.557353          228             07시     415.0           235
# 2     126.483833          323             08시     417.0            59
# 3     126.488350           59             08시     334.0           183
# 4     126.489933          183             08시     550.0           285
#
#    next_latitude  next_longitude  요일   일  weekday
# 0      33.458783      126.557353   1  29        1
# 1      33.459893      126.561624   1  29        1
# 2      33.478850      126.488350   1  29        1
# 3      33.480700      126.489933   1  29        1
# 4      33.482077      126.485355   1  29        1

# %% [markdown]
# ### train

# %%
train['week']=train['weekday'].apply(lambda x: 0 if 1 <= x <= 5 else 1)
train['week'].value_counts()
# Out:
# 0    151906
# 1     58551
# Name: week, dtype: int64

# %%
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          239             06시     266.0           227      33.457724
# 1          227             06시     333.0           228      33.458783
# 2          228             06시     415.0           235      33.459893
# 3           41             06시     578.0           249      33.484860
# 4           63             07시     374.0           221      33.485822
#
#    next_longitude  next_arrive_time  요일   일  weekday  week
# 0      126.554014                24   1  15        1     0
# 1      126.557353                36   1  15        1     0
# 2      126.561624                40   1  15        1     0
# 3      126.542928                42   1  15        1     0
# 4      126.490897                64   1  15        1     0

# %% [markdown]
# ### X_test

# %%
X_test['week']=X_test['weekday'].apply(lambda x: 0 if 1 <= x <= 5 else 1)
X_test['week'].value_counts()
# Out:
# 0    65662
# 1    26112
# Name: week, dtype: int64

# %%
X_test.head()
# Out:
#        id       date   route_id    vh_id route_nm  now_latitude  \
# 0  210457 2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458 2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459 2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460 2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461 2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance  next_station  \
# 0     126.554014          227             07시     333.0           228
# 1     126.557353          228             07시     415.0           235
# 2     126.483833          323             08시     417.0            59
# 3     126.488350           59             08시     334.0           183
# 4     126.489933          183             08시     550.0           285
#
#    next_latitude  next_longitude  요일   일  weekday  week
# 0      33.458783      126.557353   1  29        1     0
# 1      33.459893      126.561624   1  29        1     0
# 2      33.478850      126.488350   1  29        1     0
# 3      33.480700      126.489933   1  29        1     0
# 4      33.482077      126.485355   1  29        1     0

# %% [markdown]
# # 출퇴근 시간

# %%
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          239             06시     266.0           227      33.457724
# 1          227             06시     333.0           228      33.458783
# 2          228             06시     415.0           235      33.459893
# 3           41             06시     578.0           249      33.484860
# 4           63             07시     374.0           221      33.485822
#
#    next_longitude  next_arrive_time  요일   일  weekday  week
# 0      126.554014                24   1  15        1     0
# 1      126.557353                36   1  15        1     0
# 2      126.561624                40   1  15        1     0
# 3      126.542928                42   1  15        1     0
# 4      126.490897                64   1  15        1     0

# %% [markdown]
# ### train

# %% [markdown]
# 출근시간: 06 ~ 07시  /  work     :  1 <br>
# 점심시간: 12 ~ 13시  / lunch    :  2 <br>
# 퇴근시간: 16 ~ 19시  / offwork  :  3 <br>
# usually  :  0 <br>

# %%
train['traffic']='0'
train.loc[ (train['now_arrive_time']>= '06시') & (train['now_arrive_time']<='07시') ,['traffic'] ]= '1'
train.loc[ (train['now_arrive_time']>= '12시') & (train['now_arrive_time']<='13시') ,['traffic'] ]= '2'
train.loc[ (train['now_arrive_time']>= '16시') & (train['now_arrive_time']<='19시') ,['traffic'] ]= '3'

# %%
train['traffic'].value_counts()
# Out:
# 0    109009
# 3     52828
# 2     26630
# 1     21990
# Name: traffic, dtype: int64

# %%
train.head()
# Out:
#    id       date   route_id    vh_id route_nm  now_latitude  now_longitude  \
# 0   0 2019-10-15  405136001  7997025    360-1     33.456267     126.551750
# 1   1 2019-10-15  405136001  7997025    360-1     33.457724     126.554014
# 2   2 2019-10-15  405136001  7997025    360-1     33.458783     126.557353
# 3   3 2019-10-15  405136001  7997025    360-1     33.479705     126.543811
# 4   4 2019-10-15  405136001  7997025    360-1     33.485662     126.494923
#
#    now_station now_arrive_time  distance  next_station  next_latitude  \
# 0          239             06시     266.0           227      33.457724
# 1          227             06시     333.0           228      33.458783
# 2          228             06시     415.0           235      33.459893
# 3           41             06시     578.0           249      33.484860
# 4           63             07시     374.0           221      33.485822
#
#    next_longitude  next_arrive_time  요일   일  weekday  week traffic
# 0      126.554014                24   1  15        1     0       1
# 1      126.557353                36   1  15        1     0       1
# 2      126.561624                40   1  15        1     0       1
# 3      126.542928                42   1  15        1     0       1
# 4      126.490897                64   1  15        1     0       1

# %% [markdown]
# ## X_test

# %%
X_test['traffic']='0'
X_test.loc[ (X_test['now_arrive_time']>= '06시') & (X_test['now_arrive_time']<='07시') ,['traffic'] ]= '1'
X_test.loc[ (X_test['now_arrive_time']>= '12시') & (X_test['now_arrive_time']<='13시') ,['traffic'] ]= '2'
X_test.loc[ (X_test['now_arrive_time']>= '16시') & (X_test['now_arrive_time']<='19시') ,['traffic'] ]= '3'

# %%
X_test['traffic'].value_counts()
# Out:
# 0    47249
# 3    24026
# 2    10605
# 1     9894
# Name: traffic, dtype: int64

# %%
X_test.head()
# Out:
#        id       date   route_id    vh_id route_nm  now_latitude  \
# 0  210457 2019-10-29  405136001  7997025    360-1     33.457724
# 1  210458 2019-10-29  405136001  7997025    360-1     33.458783
# 2  210459 2019-10-29  405136001  7997025    360-1     33.478867
# 3  210460 2019-10-29  405136001  7997025    360-1     33.478850
# 4  210461 2019-10-29  405136001  7997025    360-1     33.480700
#
#    now_longitude  now_station now_arrive_time  distance  next_station  \
# 0     126.554014          227             07시     333.0           228
# 1     126.557353          228             07시     415.0           235
# 2     126.483833          323             08시     417.0            59
# 3     126.488350           59             08시     334.0           183
# 4     126.489933          183             08시     550.0           285
#
#    next_latitude  next_longitude  요일   일  weekday  week traffic
# 0      33.458783      126.557353   1  29        1     0       1
# 1      33.459893      126.561624   1  29        1     0       1
# 2      33.478850      126.488350   1  29        1     0       0
# 3      33.480700      126.489933   1  29        1     0       0
# 4      33.482077      126.485355   1  29        1     0       0

# %% [markdown]
# # 컬럼 드랍

# %%
train_drop = train[['id', 'date', 'route_id', 'vh_id', 'route_nm', 'now_latitude', 'now_longitude', 'now_arrive_time', 'week', 'next_longitude']]

# %% [markdown]
# ## train

# %%
train = train[['now_station', 'distance',  'next_station',  '요일', '일', 'weekday', 'traffic', 'next_arrive_time']]
train.shape
# Out:
# (210457, 8)

# %%
train.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday traffic  \
# 0          239     266.0           227   1  15        1       1
# 1          227     333.0           228   1  15        1       1
# 2          228     415.0           235   1  15        1       1
# 3           41     578.0           249   1  15        1       1
# 4           63     374.0           221   1  15        1       1
#
#    next_arrive_time
# 0                24
# 1                36
# 2                40
# 3                42
# 4                64

# %% [markdown]
# ## X_test

# %%
X_test = X_test[['now_station', 'distance',  'next_station',  '요일', '일', 'weekday', 'traffic']]
X_test.shape
# Out:
# (91774, 7)

# %%
X_test.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday traffic
# 0          227     333.0           228   1  29        1       1
# 1          228     415.0           235   1  29        1       1
# 2          323     417.0            59   1  29        1       0
# 3           59     334.0           183   1  29        1       0
# 4          183     550.0           285   1  29        1       0

# %% [markdown]
# # 데이터 타입 변경 (trian, X_test )

# %%
train['traffic'] = train['traffic'].astype(int)
X_test['traffic'] = X_test['traffic'].astype(int)

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   now_station   91774 non-null  int32
#  1   distance      91774 non-null  float64
#  2   next_station  91774 non-null  int32
#  3   요일            91774 non-null  int64
#  4   일             91774 non-null  int64
#  5   weekday       91774 non-null  int64
#  6   traffic       91774 non-null  int32
# dtypes: float64(1), int32(3), int64(3)
# memory usage: 3.9 MB

# %% [markdown]
# # 셋 나누기

# %%
X_train = train.iloc[:,:-1]
y_train = train.iloc[:,-1]

# %%
X_train.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday  traffic
# 0          239     266.0           227   1  15        1        1
# 1          227     333.0           228   1  15        1        1
# 2          228     415.0           235   1  15        1        1
# 3           41     578.0           249   1  15        1        1
# 4           63     374.0           221   1  15        1        1

# %%
X_test.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday  traffic
# 0          227     333.0           228   1  29        1        1
# 1          228     415.0           235   1  29        1        1
# 2          323     417.0            59   1  29        1        0
# 3           59     334.0           183   1  29        1        0
# 4          183     550.0           285   1  29        1        0

# %%
y_trian
# Out:
# 0         24
# 1         36
# 2         40
# 3         42
# 4         64
#           ..
# 210452    96
# 210453    50
# 210454    16
# 210455    38
# 210456    24
# Name: next_arrive_time, Length: 210457, dtype: int64

# %%
y_test
# Out:
#            id  next_arrive_time
# 0      210457                 0
# 1      210458                 0
# 2      210459                 0
# 3      210460                 0
# 4      210461                 0
# ...       ...               ...
# 91769  302350                 0
# 91770  302351                 0
# 91771  302352                 0
# 91772  302353                 0
# 91773  302354                 0
#
# [91774 rows x 2 columns]

# %%
X_train.shape, X_test.shape, y_train.shape ,y_test.shape
# Out:
# ((210457, 7), (91774, 7), (210457,), (91774, 2))

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   now_station   210457 non-null  int32
#  1   distance      210457 non-null  float64
#  2   next_station  210457 non-null  int32
#  3   요일            210457 non-null  int64
#  4   일             210457 non-null  int64
#  5   weekday       210457 non-null  int64
#  6   traffic       210457 non-null  int32
# dtypes: float64(1), int32(3), int64(3)
# memory usage: 8.8 MB

# %%
X_test
# Out:
#        now_station  distance  next_station  요일   일  weekday traffic
# 0              227     333.0           228   1  29        1       1
# 1              228     415.0           235   1  29        1       1
# 2              323     417.0            59   1  29        1       0
# 3               59     334.0           183   1  29        1       0
# 4              183     550.0           285   1  29        1       0
# ...            ...       ...           ...  ..  ..      ...     ...
# 91769          255     272.0            10   1   5        1       0
# 91770           10     447.0           245   1   5        1       0
# 91771          245     418.0            22   1   5        1       0
# 91772           22     140.0           287   1   5        1       0
# 91773          203     541.0           244   1   5        1       0
#
# [91774 rows x 7 columns]

# %%
X_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 210457 entries, 0 to 210456
# Data columns (total 7 columns):
#  #   Column        Non-Null Count   Dtype
# ---  ------        --------------   -----
#  0   now_station   210457 non-null  int32
#  1   distance      210457 non-null  float64
#  2   next_station  210457 non-null  int32
#  3   요일            210457 non-null  int64
#  4   일             210457 non-null  int64
#  5   weekday       210457 non-null  int64
#  6   traffic       210457 non-null  int32
# dtypes: float64(1), int32(3), int64(3)
# memory usage: 8.8 MB

# %%
X_test.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   now_station   91774 non-null  int32
#  1   distance      91774 non-null  float64
#  2   next_station  91774 non-null  int32
#  3   요일            91774 non-null  int64
#  4   일             91774 non-null  int64
#  5   weekday       91774 non-null  int64
#  6   traffic       91774 non-null  object
# dtypes: float64(1), int32(2), int64(3), object(1)
# memory usage: 4.2+ MB

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 7 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   now_station   91774 non-null  int32
#  1   distance      91774 non-null  float64
#  2   next_station  91774 non-null  int32
#  3   요일            91774 non-null  int64
#  4   일             91774 non-null  int64
#  5   weekday       91774 non-null  int64
#  6   traffic       91774 non-null  int32
# dtypes: float64(1), int32(3), int64(3)
# memory usage: 3.9 MB

# %% [markdown]
# # 학습데이터

# %%
input_var = list(train.columns) 
input_var.remove('next_arrive_time')

# %%
X_train = train[input_var] # 학습 데이터 선택
X_test = train['next_arrive_time'] # target 값인 Y 데이터 선택

# %%
X_test = y_train[input_var] # 시험 데이터도 선택
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-693-40e6528945c8> in <module>
# ----> 1 X_test = y_train[input_var] # 시험 데이터도 선택
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\series.py in __getitem__(self, key)
#     908             key = check_bool_indexer(self.index, key)
#     909
# --> 910         return self._get_with(key)
#     911
#     912     def _get_with(self, key):
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\series.py in _get_with(self, key)
#     956                 return self._get_values(key)
#     957
# --> 958             return self.loc[key]
#     959
#     960         return self.reindex(key)
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in __getitem__(self, key)
#    1765
#    1766             maybe_callable = com.apply_if_callable(key, self.obj)
# -> 1767             return self._getitem_axis(maybe_callable, axis=axis)
#    1768
#    1769     def _is_scalar_access(self, key: Tuple):
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _getitem_axis(self, key, axis)
#    1951                     raise ValueError("Cannot index with multidimensional key")
#    1952
# -> 1953                 return self._getitem_iterable(key, axis=axis)
#    1954
#    1955             # nested tuple slicing
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _getitem_iterable(self, key, axis)
#    1592         else:
#    1593             # A collection of keys
# -> 1594             keyarr, indexer = self._get_listlike_indexer(key, axis, raise_missing=False)
#    1595             return self.obj._reindex_with_indexers(
#    1596                 {axis: [keyarr, indexer]}, copy=True, allow_dups=True
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _get_listlike_indexer(self, key, axis, raise_missing)
#    1550
#    1551         self._validate_read_indexer(
# -> 1552             keyarr, indexer, o._get_axis_number(axis), raise_missing=raise_missing
#    1553         )
#    1554         return keyarr, indexer
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\indexing.py in _validate_read_indexer(self, key, indexer, axis, raise_missing)
#    1637             if missing == len(indexer):
#    1638                 axis_name = self.obj._get_axis_name(axis)
# -> 1639                 raise KeyError(f"None of [{key}] are in the [{axis_name}]")
#    1640
#    1641             # We (temporarily) allow for some missing keys with .loc, except in
#
# KeyError: "None of [Index(['now_station', 'distance', 'next_station', '요일', '일', 'weekday',\n       'traffic'],\n      dtype='object')] are in the [index]"

# %%
X_train.shape , X_test.shape, y_train.shape, y_test.shape
# Out:
# ((210457, 7), (210457,), (210457,), (91774, 2))

# %%
X_train.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday  traffic
# 0          239     266.0           227   1  15        1        1
# 1          227     333.0           228   1  15        1        1
# 2          228     415.0           235   1  15        1        1
# 3           41     578.0           249   1  15        1        1
# 4           63     374.0           221   1  15        1        1

# %%
X_test.head()
# Out:
# 0    24
# 1    36
# 2    40
# 3    42
# 4    64
# Name: next_arrive_time, dtype: int64

# %%
y_train.head()
# Out:
#    now_station  distance  next_station  요일   일  weekday  traffic
# 0          227     333.0           228   1  29        1        1
# 1          228     415.0           235   1  29        1        1
# 2          323     417.0            59   1  29        1        0
# 3           59     334.0           183   1  29        1        0
# 4          183     550.0           285   1  29        1        0

# %%
y_test.head()
# Out:
#        id  next_arrive_time
# 0  210457                 0
# 1  210458                 0
# 2  210459                 0
# 3  210460                 0
# 4  210461                 0

# %% [markdown]
# # XGBOOST

# %%
# 글꼴 한글 설정
plt.rc('font', family='Malgun Gothic')
plt.rc('axes', unicode_minus= False)
plt.style.use('ggplot')
pd.options.display.max_columns  = 100

# %%
from xgboost import XGBRegressor

# %%
import xgboost as xgb

# %%
xgb = XGBRegressor(random_sate=1234, max_depth=10, n_estimators=300)
xgb.fit(X_train, y_train)
xgb_pred = xgb.predict(X_test)
# Out:
# [19:29:49] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { random_sate } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.

# %%
print("훈련 세트 정확도: {:.8f}".format(xgb.score(X_train, y_train)))
# Out:
# 훈련 세트 정확도: 0.62446662

# %%
print("테스트 세트 정확도: {:.8f}".format(xgb.score(X_test, xgb_pred)))
# Out:
# 테스트 세트 정확도: 1.00000000

# %%
model_xgb = xgb.XGBRegressor(colsample_bytree=0.4603, gamma=0.0468, 
                             learning_rate=0.05, max_depth=3, 
                             min_child_weight=1.7817, n_estimators=2200,
                             reg_alpha=0.4640, reg_lambda=0.8571,
                             subsample=0.5213, silent=1,
                             random_state =7, nthread = -1)

# %%
model_xgb.fit(X_train, y_train)
# Out:
# [19:35:12] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
# XGBRegressor(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#              colsample_bynode=1, colsample_bytree=0.4603, gamma=0.0468,
#              gpu_id=-1, importance_type='gain', interaction_constraints='',
#              learning_rate=0.05, max_delta_step=0, max_depth=3,
#              min_child_weight=1.7817, missing=nan, monotone_constraints='()',
#              n_estimators=2200, n_jobs=-1, nthread=-1, num_parallel_tree=1,
#              random_state=7, reg_alpha=0.464, reg_lambda=0.8571,
#              scale_pos_weight=1, silent=1, subsample=0.5213,
#              tree_method='exact', validate_parameters=1, verbosity=None)

# %%
xgb_pred = xgb.predict(X_test)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-778-2cf59b8c8a11> in <module>
# ----> 1 xgb_pred = xgb.predict(X_test)
#
# AttributeError: module 'xgboost' has no attribute 'predict'

# %%
from sklearn.model_selection import KFold, cross_val_score, train_test_split

# %%
#Validation function
n_folds = 5

def rmsle_cv(model):
    kf = KFold(n_folds, shuffle=True, random_state=42).get_n_splits(train.values)
    rmse= np.sqrt(-cross_val_score(model, train.values, y_train, scoring="neg_mean_squared_error", cv = kf))
    return(rmse)

# %%
score = rmsle_cv(model_xgb)
print("Xgboost score: {:.4f} ({:.4f})\n".format(score.mean(), score.std()))
# Out:
# [19:38:48] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:40:35] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:42:09] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:43:43] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# [19:45:17] WARNING: C:\Users\Administrator\workspace\xgboost-win64_release_1.2.0\src\learner.cc:516:
# Parameters: { silent } might not be used.
#
#   This may not be accurate due to some parameters are only used in language bindings but
#   passed down to XGBoost core.  Or some parameters are not used but slip through this
#   verification. Please open an issue if you find above cases.
#
#
# Xgboost score: 1.1732 (0.2122)

# %%
score
# Out:
# array([1.4207543 , 1.42356365, 1.10919951, 0.99385398, 0.91857136])

# %%
Xgboost score
# Out:
#   File "<ipython-input-792-2c78305b6fc2>", line 1
#     Xgboost score
#                 ^
# SyntaxError: invalid syntax

# %%
pd.DataFrame(xgb_pred)
# Out:
#                 0
# 0       66.446129
# 1      129.199219
# 2      114.953415
# 3       56.397346
# 4      155.797943
# ...           ...
# 91769   99.988625
# 91770   70.291321
# 91771  116.657333
# 91772   37.365311
# 91773  110.662994
#
# [91774 rows x 1 columns]

# %%
y_test

# %%
score
# Out:
# array([1.4207543 , 1.42356365, 1.10919951, 0.99385398, 0.91857136])

# %% [markdown]
# # 파일저장

# %%
y_test = pd.read_csv('data/submission_제출양식.csv')
print(y_test.shape)
# Out:
# (91774, 2)

# %%
score.shape
# Out:
# (5,)

# %%
y_test['next_arrive_time'] = score
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-794-48284d6e0804> in <module>
# ----> 1 y_test['next_arrive_time'] = score
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\frame.py in __setitem__(self, key, value)
#    2936         else:
#    2937             # set column
# -> 2938             self._set_item(key, value)
#    2939
#    2940     def _setitem_slice(self, key, value):
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _set_item(self, key, value)
#    2998
#    2999         self._ensure_valid_index(value)
# -> 3000         value = self._sanitize_column(key, value)
#    3001         NDFrame._set_item(self, key, value)
#    3002
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\frame.py in _sanitize_column(self, key, value, broadcast)
#    3634
#    3635             # turn me into an ndarray
# -> 3636             value = sanitize_index(value, self.index, copy=False)
#    3637             if not isinstance(value, (np.ndarray, Index)):
#    3638                 if isinstance(value, list) and len(value) > 0:
#
# C:\Anaconda3_64\lib\site-packages\pandas\core\internals\construction.py in sanitize_index(data, index, copy)
#     609
#     610     if len(data) != len(index):
# --> 611         raise ValueError("Length of values does not match length of index")
#     612
#     613     if isinstance(data, ABCIndexClass) and not copy:
#
# ValueError: Length of values does not match length of index

# %%
y_test
# Out:
#            id  next_arrive_time
# 0      210457         66.446129
# 1      210458        129.199219
# 2      210459        114.953415
# 3      210460         56.397346
# 4      210461        155.797943
# ...       ...               ...
# 91769  302350         99.988625
# 91770  302351         70.291321
# 91771  302352        116.657333
# 91772  302353         37.365311
# 91773  302354        110.662994
#
# [91774 rows x 2 columns]

# %%
import pandas as pd

# %%
y_test.to_csv('bus.csv', index=False)

# %%
feature_names = X_train.columns.tolist()

sns.barplot(x=xgb.feature_importances_, y = feature_names)

# %%
y_train.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 91774 entries, 0 to 91773
# Data columns (total 8 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   now_station   91774 non-null  int32
#  1   distance      91774 non-null  float64
#  2   next_station  91774 non-null  int32
#  3   요일            91774 non-null  int64
#  4   일             91774 non-null  int64
#  5   weekday       91774 non-null  int64
#  6   week          91774 non-null  int64
#  7   traffic       91774 non-null  int32
# dtypes: float64(1), int32(3), int64(4)
# memory usage: 4.6 MB

# %%
xgb.feature_importances_
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-904-66a5accea0d8> in <module>
# ----> 1 xgb.feature_importances_
#
# C:\Anaconda3_64\lib\site-packages\xgboost\sklearn.py in feature_importances_(self)
#     688             raise AttributeError(
#     689                 'Feature importance is not defined for Booster type {}'
# --> 690                 .format(self.booster))
#     691         b = self.get_booster()
#     692         score = b.get_score(importance_type=self.importance_type)
#
# AttributeError: Feature importance is not defined for Booster type None

# %%
print("훈련 세트 정확도: {:.8f}".format(xgb.score(X_train, y_train)))
# Out:
# 훈련 세트 정확도: 0.87025392

# %%
feature_names = X_train.columns.tolist()

sns.barplot(x=xgb.feature_importances_, y = feature_names)

# %%
print('훈련 정확도: {:.8f}'.format(xgb.score(X-train,y_train)))
print("테스트 세트 정확도: {:.8f}".format(xgb.score(y_test, y_test)))
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-116-36cc23f446b3> in <module>
# ----> 1 print('훈련 정확도: {:.8f}'.format(xgb.score(X-train,y_train)))
#       2 print("테스트 세트 정확도: {:.8f}".format(xgb.score(x_test, y_test)))
#
# C:\Anaconda3_64\lib\site-packages\sklearn\base.py in score(self, X, y, sample_weight)
#     549
#     550         from .metrics import r2_score
# --> 551         y_pred = self.predict(X)
#     552         return r2_score(y, y_pred, sample_weight=sample_weight)
#     553
#
# C:\Anaconda3_64\lib\site-packages\xgboost\sklearn.py in predict(self, data, output_margin, ntree_limit, validate_features, base_margin)
#     594         # pylint: disable=missing-docstring,invalid-name
#     595         test_dmatrix = DMatrix(data, base_margin=base_margin,
# --> 596                                missing=self.missing, nthread=self.n_jobs)
#     597         # get ntree_limit to use - if none specified, default to
#     598         # best_ntree_limit if defined, otherwise 0.
#
# C:\Anaconda3_64\lib\site-packages\xgboost\core.py in __init__(self, data, label, weight, base_margin, missing, silent, feature_names, feature_types, nthread)
#     436             threads=self.nthread,
#     437             feature_names=feature_names,
# --> 438             feature_types=feature_types)
#     439         assert handle is not None
#     440         self.handle = handle
#
# C:\Anaconda3_64\lib\site-packages\xgboost\data.py in dispatch_data_backend(data, missing, threads, feature_names, feature_types)
#     502     if _is_pandas_df(data):
#     503         return _from_pandas_df(data, missing, threads,
# --> 504                                feature_names, feature_types)
#     505     if _is_pandas_series(data):
#     506         return _from_pandas_series(data, missing, threads, feature_names,
#
# C:\Anaconda3_64\lib\site-packages\xgboost\data.py in _from_pandas_df(data, missing, nthread, feature_names, feature_types)
#     217 def _from_pandas_df(data, missing, nthread, feature_names, feature_types):
#     218     data, feature_names, feature_types = _transform_pandas_df(
# --> 219         data, feature_names, feature_types)
#     220     return _from_numpy_array(data, missing, nthread, feature_names,
#     221                              feature_types)
#
# C:\Anaconda3_64\lib\site-packages\xgboost\data.py in _transform_pandas_df(data, feature_names, feature_types, meta, meta_type)
#     183         msg = """DataFrame.dtypes for data must be int, float or bool.
#     184                 Did not expect the data types in fields """
# --> 185         raise ValueError(msg + ', '.join(bad_fields))
#     186
#     187     if feature_names is None and meta is None:
#
# ValueError: DataFrame.dtypes for data must be int, float or bool.
#                 Did not expect the data types in fields date, next_station, now_arrive_time, now_station, route_nm

# %%
X-train
# Out:
#        date  distance  id  next_arrive_time  next_latitude  next_longitude  \
# 0       NaN       0.0   0               NaN            0.0             0.0
# 1       NaN       0.0   0               NaN            0.0             0.0
# 2       NaN       0.0   0               NaN            0.0             0.0
# 3       NaN       0.0   0               NaN            0.0             0.0
# 4       NaN       0.0   0               NaN            0.0             0.0
# ...     ...       ...  ..               ...            ...             ...
# 210452  NaN       0.0   0               NaN            0.0             0.0
# 210453  NaN       0.0   0               NaN            0.0             0.0
# 210454  NaN       0.0   0               NaN            0.0             0.0
# 210455  NaN       0.0   0               NaN            0.0             0.0
# 210456  NaN       0.0   0               NaN            0.0             0.0
#
#        next_station now_arrive_time  now_latitude  now_longitude now_station  \
# 0               NaN             NaN           0.0            0.0         NaN
# 1               NaN             NaN           0.0            0.0         NaN
# 2               NaN             NaN           0.0            0.0         NaN
# 3               NaN             NaN           0.0            0.0         NaN
# 4               NaN             NaN           0.0            0.0         NaN
# ...             ...             ...           ...            ...         ...
# 210452          NaN             NaN           0.0            0.0         NaN
# 210453          NaN             NaN           0.0            0.0         NaN
# 210454          NaN             NaN           0.0            0.0         NaN
# 210455          NaN             NaN           0.0            0.0         NaN
# 210456          NaN             NaN           0.0            0.0         NaN
#
#         route_id route_nm  vh_id
# 0              0      NaN      0
# 1              0      NaN      0
# 2              0      NaN      0
# 3              0      NaN      0
# 4              0      NaN      0
# ...          ...      ...    ...
# 210452         0      NaN      0
# 210453         0      NaN      0
# 210454         0      NaN      0
# 210455         0      NaN      0
# 210456         0      NaN      0
#
# [210457 rows x 14 columns]

# %%
X.columns
# Out:
# Index(['id', 'route_id', 'vh_id', 'now_latitude', 'now_longitude', 'distance',
#        'next_latitude', 'next_longitude'],
#       dtype='object')

# %%
train.describe(include='object')
# Out:
#               date route_nm now_station now_arrive_time next_station
# count       210457   210457      210457          210457       210457
# unique          14       21         348              20          351
# top     2019-10-15   365-22   남국원(아라방면)             08시          은남동
# freq         15980    31941        3361           13838         3519

# %%
list(train['now_station'].value_counts())
# Out:
# [3361,
#  3098,
#  3093,
#  3056,
#  2789,
#  2728,
#  2606,
#  2474,
#  2363,
#  2290,
#  2281,
#  2232,
#  2215,
#  2192,
#  2166,
#  2106,
#  2090,
#  2047,
#  2021,
#  1997,
#  1939,
#  1861,
#  1846,
#  1841,
#  1830,
#  1768,
#  1566,
#  1535,
#  1514,
#  1486,
#  1450,
#  1440,
#  1371,
#  1365,
#  1343,
#  1313,
#  1311,
#  1292,
#  1264,
#  1240,
#  1235,
#  1209,
#  1199,
#  1187,
#  1180,
#  1172,
#  1160,
#  1121,
#  1115,
#  1109,
#  1104,
#  1100,
#  1090,
#  1071,
#  1044,
#  1044,
#  1039,
#  1038,
#  1037,
#  1034,
#  1034,
#  1022,
#  1020,
#  1020,
#  1009,
#  978,
#  964,
#  953,
#  942,
#  936,
#  921,
#  912,
#  909,
#  906,
#  906,
#  875,
#  874,
#  857,
#  854,
#  828,
#  820,
#  814,
#  810,
#  807,
#  779,
#  774,
#  763,
#  763,
#  762,
#  758,
#  749,
#  729,
#  725,
#  708,
#  704,
#  691,
#  690,
#  686,
#  686,
#  662,
#  654,
#  651,
#  641,
#  640,
#  632,
#  628,
#  624,
#  624,
#  613,
#  610,
#  582,
#  580,
#  579,
#  577,
#  574,
#  573,
#  572,
#  570,
#  568,
#  568,
#  566,
#  563,
#  559,
#  546,
#  545,
#  544,
#  534,
#  533,
#  521,
#  518,
#  517,
#  511,
#  504,
#  504,
#  502,
#  502,
#  498,
#  496,
#  492,
#  492,
#  488,
#  487,
#  474,
#  467,
#  465,
#  464,
#  464,
#  461,
#  461,
#  460,
#  454,
#  449,
#  449,
#  445,
#  443,
#  440,
#  437,
#  431,
#  429,
#  426,
#  423,
#  422,
#  420,
#  419,
#  414,
#  408,
#  406,
#  404,
#  404,
#  403,
#  401,
#  398,
#  397,
#  396,
#  395,
#  394,
#  388,
#  387,
#  386,
#  386,
#  381,
#  378,
#  375,
#  374,
#  374,
#  372,
#  371,
#  371,
#  371,
#  369,
#  366,
#  365,
#  365,
#  364,
#  361,
#  359,
#  357,
#  356,
#  355,
#  351,
#  350,
#  349,
#  340,
#  338,
#  337,
#  335,
#  334,
#  331,
#  324,
#  320,
#  317,
#  312,
#  311,
#  311,
#  311,
#  310,
#  308,
#  306,
#  297,
#  296,
#  296,
#  293,
#  286,
#  282,
#  279,
#  277,
#  276,
#  276,
#  276,
#  275,
#  274,
#  273,
#  273,
#  272,
#  271,
#  270,
#  270,
#  269,
#  268,
#  259,
#  258,
#  258,
#  253,
#  253,
#  253,
#  253,
#  252,
#  249,
#  249,
#  243,
#  242,
#  241,
#  240,
#  240,
#  234,
#  234,
#  234,
#  227,
#  227,
#  227,
#  226,
#  224,
#  222,
#  222,
#  213,
#  213,
#  211,
#  206,
#  205,
#  205,
#  204,
#  204,
#  202,
#  199,
#  198,
#  197,
#  195,
#  191,
#  189,
#  179,
#  178,
#  177,
#  177,
#  177,
#  176,
#  172,
#  170,
#  169,
#  166,
#  162,
#  156,
#  155,
#  154,
#  154,
#  152,
#  150,
#  142,
#  142,
#  140,
#  139,
#  136,
#  135,
#  132,
#  132,
#  128,
#  124,
#  122,
#  122,
#  121,
#  118,
#  117,
#  115,
#  112,
#  107,
#  104,
#  99,
#  92,
#  92,
#  82,
#  80,
#  80,
#  77,
#  77,
#  76,
#  72,
#  72,
#  70,
#  68,
#  63,
#  63,
#  61,
#  60,
#  57,
#  56,
#  54,
#  53,
#  49,
#  46,
#  35,
#  35,
#  33,
#  33,
#  28,
#  25,
#  21,
#  18,
#  11,
#  7]

# %%
list(train['now_station'].values)
# Out:
# ['제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제주여자중고등학교(아라방면)',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '남국원(아라방면)',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제주여자중고등학교(아라방면)',
#  '아라주공아파트',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주지방법원(아라방면)',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '죽성마을 입구',
#  '남국사',
#  '제주대학교입구',
#  '제주대학교',
#  '남국원(아라방면)',
#  '제원아파트',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주지방법원(아라방면)',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '도호동',
#  '연동주민센터',
#  '오라3동',
#  '제주버스터미널',
#  '한국병원',
#  '탐라장애인 종합복지관',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '인다마을',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '부영아파트',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제대마을',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '고산동산(아라방면)',
#  '제원아파트',
#  '부영아파트',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '제주대학교입구',
#  '제대아파트',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '오라3동',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '고산동산(아라방면)',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제주대학교',
#  '남국원(아라방면)',
#  '제원아파트',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제주여자중고등학교(아라방면)',
#  '도호동',
#  '은남동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '제주버스터미널',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '남국원(아라방면)',
#  '제주지방법원(아라방면)',
#  '도호동',
#  '은남동',
#  '제원아파트',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '남국원(아라방면)',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '아라초등학교',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '남국사',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '아라초등학교',
#  '남국원(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '제대마을',
#  '아라초등학교',
#  '고산동산(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  '은남동',
#  '도호동',
#  '연동주민센터',
#  '제주도청 신제주로터리',
#  '연동입구',
#  '오라3동',
#  '월구마을',
#  '동성마을',
#  '제주버스터미널',
#  '한국병원',
#  '남서광마을입구',
#  '남서광마을',
#  '탐라장애인 종합복지관',
#  '제주시청(아라방면)',
#  '고산동산(아라방면)',
#  '제주지방법원(아라방면)',
#  '제주중앙여자고등학교(아라방면)',
#  '제주여자중고등학교(아라방면)',
#  '남국원(아라방면)',
#  '아라초등학교',
#  '아라주공아파트',
#  '인다마을',
#  '제주대학교병원',
#  '제주대학교입구',
#  '제대마을',
#  '제대아파트',
#  '아라초등학교',
#  '남국원(아라방면)',
#  '도호동',
#  '한라중학교/부영아파트',
#  '대림2차아파트',
#  '연동대림1차아파트',
#  '케이티앤지',
#  '롯데마트',
#  '원노형',
#  '노형오거리',
#  '남녕고등학교',
#  '한라병원',
#  '삼무공원사거리',
#  '제원아파트',
#  ...]
